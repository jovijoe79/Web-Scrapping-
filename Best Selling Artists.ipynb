# %% [markdown]
# # Best selling Artists

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://chartmasters.org/best-selling-artists-of-all-time/'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://chartmasters.org/xmlrpc.php" rel="pingback"/>
# ...

# %%
table = soup.find('table')

# %%
table_header = table.find_all('th')

table_headers = [head.text.strip() for head in table_header]
#print(table_headers)

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = table_headers)

# %%
column_data = table.find_all('tr')
#column_data

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    single_data = [data.text.strip() for data in row_data]
    #print(single_data)
    length = len(df)
    df.loc[length] = single_data

# %%
df
# Out:
#    #       artist_spotify_id  g# Pic               Artist Studio Albums (EAS)  \
# 0     3WrFJ7ztbogyGnTHbHJFl2   1              The Beatles         160,650,000
# 1     3fMbdgg4jU18AjLCKBhRSm   2          Michael Jackson         182,600,000
# 2     43ZHCT0cAZBISjO8DG9PnE   3            Elvis Presley          53,150,000
# 3     1dfeR4HaWDbWqFHLkxsg1d   4                    Queen          90,230,000
# 4     6tbjWDEIzxoDsBA1FuhfPW   5                  Madonna         146,450,000
# 5     22bE4uQ6baNwSHPVcDxLCe   6       The Rolling Stones         113,800,000
# 6     0k17h0D3J5VfsdmQ1iZtE9   7               Pink Floyd         169,600,000
# 7     1Mxqyy3pSjf8kZZL4QVxS0   8            Frank Sinatra          49,764,000
# 8     7dGJo4pcD2V6oG8kP0tJRR   9                   Eminem          98,650,000
# 9     06HL4z0CvFAxyc27GXpf02  10             Taylor Swift          58,344,000
# 10    3PhoLpVuITZKcymswpck5b  11               Elton John          88,630,000
# ...

# %%
df.to_csv(r'C:\Users\DELL\Documents\Scraped Data\Best Selling Artists.csv', index = False)
